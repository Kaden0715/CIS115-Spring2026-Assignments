# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week14/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py

# IMPORT STATEMENTS
# (None)

# CLASS DEFINITIONS
# 1. Define class Book
class Book:
# 2. Define __init__(self, title, author)
    def __init__(self, title, author):
# 3. Set title and author
        self.title = title
        self.author = author
# 4. Set is_available to True
        self.is_available = True
# 5. Define __str__(self)
    def __str__(self):
# 6. Return the string
        if self.is_available == True:
            status = "Available"
        else:
            status = "Checked Out"
        return self.title + " by " + self.author + " - " + status
# 7. Define checkout(self)
    def checkout(self):
# 8. Set is_available to False
        self.is_available = False
# 9. Define return_book(self)
    def return_book(self):
# 10. Set is_available to True
        self.is_available = True

# PROGRAM LOGIC
# 1. Create two book objects
book1 = Book("Think Python", "Allen Downey")
book2 = Book("The Hobbit", "J.R.R. Tolkien")
# 2. Print one attribute
print(book1.title)
# 3. Print both books
print("\n--- Library Status ---")
print(book1)
print(book2)
# 4. Run checkout on one book
book2.checkout()
print("\n--- Updated Status ---")
print(book1)
print(book2)
# Out:
# Think Python
#
# --- Library Status ---
# Think Python by Allen Downey - Available
# The Hobbit by J.R.R. Tolkien - Available
#
# --- Updated Status ---
# Think Python by Allen Downey - Available
# The Hobbit by J.R.R. Tolkien - Checked Out
