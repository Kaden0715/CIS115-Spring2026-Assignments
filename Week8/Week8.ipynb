# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week8/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define is_palindrome(word)
# 2. Convert word to lowercase
# 3. Reverse word using slicing
# 4. Compare lowercase word to reversed word
#    - If equal, return True
#    - Else, return False

# PROGRAM LOGIC
# 1. Input for word
# 2. Call is_palindrome(word)
#    - Store returned value
# 3. If True, print is a palindrome
# 4. Else, print is not a palindrome
