# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
# 2. Inside the function, use string multiplication (*) for a border line.
    print("*" * 25)
# 3. Print the bio details using the parameter names.
    print("Name: " + name + ", Age: " + str(age) + " Goal: " + goal + ".")
# 4. Print bottom border
    print("*" * 25)
    print()

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Kaden Carr", 19, "I want to make a lot of money")
# 2. Call print_bio using a famous person.
print_bio("Elon Musk", 54, "I want to travel space")
# 3. Call print_bio using fictional character.
print_bio("Batman", 35, "I want to protect Gotham City")
# Out:
# *************************
# Name: Kaden Carr, Age: 19 Goal: I want to make a lot of money.
# *************************
#
# *************************
# Name: Elon Musk, Age: 54 Goal: I want to travel space.
# *************************
#
# *************************
# Name: Batman, Age: 35 Goal: I want to protect Gotham City.
# *************************
