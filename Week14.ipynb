# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py

# IMPORT STATEMENTS
# (None)

# CLASS DEFINITIONS
# 1. Define class Book
# 2. Define __init__(self, title, author)
# 3. Set title and author
# 4. Set is_available to True
# 5. Define __str__(self)
# 6. Return the string
# 7. Define checkout(self)
# 8. Set is_available to False
# 9. Define return_book(self)
# 10. Set is_available to True

# PROGRAM LOGIC
# 1. Create two book objects
# 2. Print one attribute
# 3. Print both books
# 4. Run checkout on one book
