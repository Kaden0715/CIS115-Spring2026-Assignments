# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week15/Week15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: task_manager.py

# IMPORT STATEMENTS
# (None)

# PROGRAM LOGIC
# 1. Create empty task list
tasks = []
# 2. Use loop to keep program running
while True:
# 3. Ask user for action
    print("\n1. Add Task")
    print("2. View Tasks")
    print("3. Complete Task")
    print("4. What is next?")
    print("5. Exit")
    choice = input("Choose an option: ")
# 4. Add task
    if choice == "1":
        name = input("Enter task name: ")
        priority = input("Enter priority (1=High, 2=Medium, 3=Low): ")
        tasks.append((name, priority))
# 5. View tasks
    elif choice == "2":
        print("\n--- Task List ---")
        for i in range(len(tasks)):
            print(str(i) + ". " + tasks[i][0] + " (Priority " + tasks[i][1] + ")")
# 6. Complete task
    elif choice == "3":
        index = int(input("Enter task number to complete: "))
        completed = tasks.pop(index)
# 7. Save completed task to file
        file = open("history.txt", "a")
        file.write(completed[0] + "\n")
        file.close()

        print("Task completed and saved.")
# 8. What is next
    elif choice == "4":
        found = False

        for t in tasks:
            if t[1] == "1":
                print("Next high priority task: " + t[0])
                found = True
                break

        if found == False:
            print("No high priority tasks. You're doing great!")
# 9. Exit
    elif choice == "5":
        break
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 1
# Enter task name: work
# Enter priority (1=High, 2=Medium, 3=Low): 2
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 1
# Enter task name: school
# Enter priority (1=High, 2=Medium, 3=Low): 1
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 1
# Enter task name: dishes
# Enter priority (1=High, 2=Medium, 3=Low): 3
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 4
# Next high priority task: school
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 3
# Enter task number to complete: 1
# Task completed and saved.
#
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is next?
# 5. Exit
# Choose an option: 4
# No high priority tasks. You're doing great!
#
# 1. Add Task
# 2. View Tasks
# ...
