# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaden0715/CIS115-Spring2026-Assignments/blob/main/Week9/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py

# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_bill(classification, days, miles)
def calculate_bill(classification, days, miles):
# 2. Determine daily rate based on classification
#    - B = $40/day
#    - S = $60/day
#    - L = $80/day
    if classification == "B":
        rate = 40
    elif classification == "S":
        rate = 60
    else:
        rate = 80
# 3. Calculate charged miles
#    - First 100 miles free
#    - Miles over 100 charged at $0.35 per mile
    if miles > 100:
        charged_miles = miles - 100
    else:
        charged_miles = 0
# 4. Calculate total bill
#    - (daily rate * days) + mileage charge
    mileage_charge = charged_miles * 0.35
    total_bill = (rate * days) + mileage_charge
# 5. Return total bill
    return total_bill

# PROGRAM LOGIC
# 1. Ask user for classification code
code = input("Enter classification code (B, S, L): ").upper()
# 2. Validate classification (B, S, L)
while code not in ["B", "S", "L"]:
    print("Invalid code. Please enter B, S, or L.")
    code = input("Enter classification code (B, S, L): ").upper()
# 3. Ask for start odometer
start = float(input("Start Odometer: "))
# 4. Ask for end odometer
end = float(input("End Odometer: "))
# 5. Calculate total miles driven
miles = end - start
# 6. Ask for days rented
days = int(input("Days Rented: "))
# 7. Call calculate_bill() and store returned value
# 8. Determine full classification name
# 9. Determine charged miles
# 10. Print rental summary
# Out:
# Enter classification code (B, S, L): s
# Start Odometer: 1000
# End Odometer: 1250
# Days Rented: 3
